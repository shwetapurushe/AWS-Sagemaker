# %%
# Import all the required libraries

import os;
import numpy as np;
import pandas as pd;

# %% [markdown]
# Importing the input data from an S3 bucket

# %%
s3_bkt = "s3://aws-shweta-poc"
s3_json_in = s3_bkt + "/input_data/SCalcET8_out.json"
df = pd.read_json(s3_json_in,'index')

# %%
df.head(3)
# Out:
#                                                          cendoc  \
# SCalcET8 1.1  <cl:sect2 xmlns:cl="http://xml.cengage-learnin...
# SCalcET8 1.2  <cl:sect2 xmlns:cl="http://xml.cengage-learnin...
# SCalcET8 1.3  <cl:sect2 xmlns:cl="http://xml.cengage-learnin...
#
#                        chaptername   narrativeid  \
# SCalcET8 1.1  Functions and Models  SCalcET8 1.1
# SCalcET8 1.2  Functions and Models  SCalcET8 1.2
# SCalcET8 1.3  Functions and Models  SCalcET8 1.3
#
#                                                       plaintext  \
# SCalcET8 1.1   Four Ways to Represent a Function 1.1  Functi...
# SCalcET8 1.2   Mathematical Models: A Catalog of Essential F...
# SCalcET8 1.3   New Functions from Old Functions 1.3  In this...
#
#                                                     sectionname  \
# SCalcET8 1.1                  Four Ways to Represent a Function
# SCalcET8 1.2  Mathematical Models: A Catalog of Essential Fu...
# SCalcET8 1.3                   New Functions from Old Functions
#
#                                     titlename
# SCalcET8 1.1  Calculus: Early Transcendentals
# SCalcET8 1.2  Calculus: Early Transcendentals
# SCalcET8 1.3  Calculus: Early Transcendentals

# %% [markdown]
# Specifying the output location

# %%
# output CSV with just id and text columns - used as input to comprehend topic model

#specify the location
s3_csv_out = s3_bkt + "/output_data/narrative.csv"
df.to_csv('/tmp/narrative.csv', columns = ['narrativeid','chaptername','sectionname','plaintext'], index=False, header=False) #temp file
# !aws s3 cp '/tmp/narrative.csv' '{s3_csv_out}' #copy temp file to output location
# Out:
# upload: ../../../../../tmp/narrative.csv to s3://aws-shweta-poc/output_data/narrative.csv

# %% [markdown]
# ## 2. Topic Modeling using Comprehend

# %%
import time
from time import gmtime, strftime
import boto3

# %%
#creating the client
client = boto3.client('comprehend')

# %%
client

# %%
# Q. How was this initial number of topics decided ?
num_topics = 20

# %%
s3_comprehend_out = s3_bkt + "/output_data/comprehend_out/" #where the results will be written


# We need two roles 
# One is the Sagemaker execution role when we create the Sagemaker notebook instance
# Two is the Comprehend role which can be created from the Comprehend Console > submit a job > use the role created in the console 
# below for future jobs
#
comprehend_role = 'arn:aws:iam::684066638289:role/service-role/AmazonComprehendServiceRole-shweta-fromconsole'




#Starting the Comprehend Job. 
response = client.start_topics_detection_job(
    InputDataConfig={
        'S3Uri': s3_csv_out,
        'InputFormat': 'ONE_DOC_PER_LINE'
    },
    OutputDataConfig={
        'S3Uri': s3_comprehend_out
    },
    DataAccessRoleArn=comprehend_role,
    JobName='narrative_topic_model',
    NumberOfTopics=num_topics
)

# %%
jobid = response['JobId']
status = response['JobStatus']

# %%
while status in ['SUBMITTED', 'IN_PROGRESS']:
    response = client.describe_topics_detection_job(
        JobId=jobid
    )
    status = response['TopicsDetectionJobProperties']['JobStatus']
    print(strftime("%H:%M:%S", gmtime()) + ": " + status)
    time.sleep(120)
# Out:
# 14:43:38: IN_PROGRESS
# 14:45:38: IN_PROGRESS
# 14:47:38: IN_PROGRESS
# 14:49:38: IN_PROGRESS
# 14:51:38: IN_PROGRESS
# 14:53:38: IN_PROGRESS
# 14:55:38: IN_PROGRESS
# 14:57:38: IN_PROGRESS
# 14:59:39: IN_PROGRESS
# 15:01:39: IN_PROGRESS
# 15:03:39: IN_PROGRESS
# 15:05:39: IN_PROGRESS
# 15:07:39: IN_PROGRESS
# 15:09:39: COMPLETED

# %%
#output_data = response['TopicsDetectionJobProperties']['OutputDataConfig']['S3Uri']
response
# Out:
# {'TopicsDetectionJobProperties': {'JobId': '2519531e0d0be34d3c44796b76eb139f',
#   'JobName': 'narrative_topic_model',
#   'JobStatus': 'COMPLETED',
#   'SubmitTime': datetime.datetime(2019, 6, 6, 14, 43, 34, 636000, tzinfo=tzlocal()),
#   'EndTime': datetime.datetime(2019, 6, 6, 15, 9, 15, 36000, tzinfo=tzlocal()),
#   'InputDataConfig': {'S3Uri': 's3://aws-poc-shweta/output_data/narrative.csv',
#    'InputFormat': 'ONE_DOC_PER_LINE'},
#   'OutputDataConfig': {'S3Uri': 's3://aws-poc-shweta/output_data/comprehend_out/684066638289-TOPICS-2519531e0d0be34d3c44796b76eb139f/output/output.tar.gz'},
#   'NumberOfTopics': 20,
#   'DataAccessRoleArn': 'arn:aws:iam::684066638289:role/service-role/AmazonComprehendServiceRole-shweta-fromconsole'},
#  'ResponseMetadata': {'RequestId': '1b031430-886d-11e9-bab1-658f388d00c0',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '1b031430-886d-11e9-bab1-658f388d00c0',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '586',
#    'date': 'Thu, 06 Jun 2019 15:09:39 GMT'},
#   'RetryAttempts': 0}}

# %%
output_data = response['TopicsDetectionJobProperties']['OutputDataConfig']['S3Uri']

# %%
output_data
# Out:
# 's3://aws-poc-shweta/output_data/comprehend_out/684066638289-TOPICS-2519531e0d0be34d3c44796b76eb139f/output/output.tar.gz'

# %%
# !aws s3 cp {output_data} /tmp # copy this data to a temp location
# Out:
# download: s3://aws-poc-shweta/output_data/comprehend_out/684066638289-TOPICS-2519531e0d0be34d3c44796b76eb139f/output/output.tar.gz to ../../../../tmp/output.tar.gz

# %%
# !cd /tmp; tar -xvzf ./output.tar.gz
# Out:
# topic-terms.csv
# doc-topics.csv

# %% [markdown]
# ### Examining the topics

# %%
df_topics = pd.read_csv('/tmp/doc-topics.csv')

# split docname into filename and lineno
df_topics[['filename','line']] = df_topics.docname.str.split(":",expand=True,)

# reorder columns and drop docname
df_topics = df_topics[['line','filename','topic','proportion']]

# line is numeric
df_topics['line'] = pd.to_numeric(df_topics['line'], errors='coerce')
 
# sort by line and proportion (significance)
df_topics = df_topics.sort_values(by=['line','proportion'],ascending=[True,False])


# Q. How was this significance filter decided ?
# filter: significant topics only
df_topics = df_topics[df_topics['proportion'] > .5]
df_topics.head(5)
# Out:
#      line       filename  topic  proportion
# 51      0  narrative.csv      2    0.850824
# 360     1  narrative.csv      2    0.796357
# 31      2  narrative.csv      2    0.936723
# 644     3  narrative.csv      2    0.917235
# 492     4  narrative.csv      2    0.920330

# %% [markdown]
# #### Add topic to narrative chapter/section info

# %%
df_text = pd.read_csv('/tmp/narrative.csv', header=None, names=['id','chaptername','sectionname','plaintext'])
df_text.head(2)
# Out:
#              id           chaptername  \
# 0  SCalcET8 1.1  Functions and Models
# 1  SCalcET8 1.2  Functions and Models
#
#                                          sectionname  \
# 0                  Four Ways to Represent a Function
# 1  Mathematical Models: A Catalog of Essential Fu...
#
#                                            plaintext
# 0   Four Ways to Represent a Function 1.1  Functi...
# 1   Mathematical Models: A Catalog of Essential F...

# %% [markdown]
# Combining the section metadata with topic results returned

# %%
df_sectiontopics = pd.merge(df_text, df_topics, left_index=True, right_on='line')
df_sectiontopics.head(2)
# Out:
#                id           chaptername  \
# 51   SCalcET8 1.1  Functions and Models
# 360  SCalcET8 1.2  Functions and Models
#
#                                            sectionname  \
# 51                   Four Ways to Represent a Function
# 360  Mathematical Models: A Catalog of Essential Fu...
#
#                                              plaintext  line       filename  \
# 51    Four Ways to Represent a Function 1.1  Functi...     0  narrative.csv
# 360   Mathematical Models: A Catalog of Essential F...     1  narrative.csv
#
#      topic  proportion
# 51       2    0.850824
# 360      2    0.796357

# %% [markdown]
# #### Add terms for each topic

# %%
df_terms = pd.read_csv('/tmp/topic-terms.csv')
df_terms.head(2)
# Out:
#    topic term    weight
# 0      0   x2  0.047832
# 1      0   y2  0.038478

# %%
# reshape to get one row per topic, with terms concatenated into a list
df_termslist = df_terms.groupby('topic').apply(lambda x: list(x['term'].values)).to_frame(name='terms')
df_termslist.head(2)
# Out:
#                                                    terms
# topic
# 0      [x2, y2, integral, region, coordinate, plane, ...
# 1      [ft, force, work, rate, mass, length, cm, time...

# %% [markdown]
# Combining above topic dataframe with terms above

# %%
# combine terms with sectiontopics
df_sectiontopicsterms = pd.merge(df_sectiontopics, df_termslist, right_index=True, left_on='topic')
df_sectiontopicsterms = df_sectiontopicsterms[['line','id','chaptername','sectionname','topic', 'terms']].sort_values(by='line')

# %%
pd.set_option('display.max_colwidth', 0)
pd.set_option('display.max_rows', 100)
df_sectiontopicsterms
# Out:
#      line              id                                 chaptername  \
# 51   0     SCalcET8 1.1    Functions and Models
# 360  1     SCalcET8 1.2    Functions and Models
# 31   2     SCalcET8 1.3    Functions and Models
# 644  3     SCalcET8 1.4    Functions and Models
# 492  4     SCalcET8 1.5    Functions and Models
# 163  5     SCalcET8 2.1    Limits and Derivatives
# 12   6     SCalcET8 2.2    Limits and Derivatives
# 558  7     SCalcET8 2.3    Limits and Derivatives
# 538  8     SCalcET8 2.4    Limits and Derivatives
# 624  9     SCalcET8 2.5    Limits and Derivatives
# 298  10    SCalcET8 2.6    Limits and Derivatives
# 591  11    SCalcET8 2.7    Limits and Derivatives
# 79   12    SCalcET8 2.8    Limits and Derivatives
# 667  19    SCalcET8 3.7    Differentiation Rules
# 123  20    SCalcET8 3.8    Differentiation Rules
# 315  21    SCalcET8 3.9    Differentiation Rules
# 431  22    SCalcET8 3.10   Differentiation Rules
# 404  23    SCalcET8 3.11   Differentiation Rules
# 477  24    SCalcET8 4.1    Applications of Differentiation
# 0    25    SCalcET8 4.2    Applications of Differentiation
# 611  26    SCalcET8 4.3    Applications of Differentiation
# 278  27    SCalcET8 4.4    Applications of Differentiation
# 110  29    SCalcET8 4.6    Applications of Differentiation
# 578  31    SCalcET8 4.8    Applications of Differentiation
# 342  33    SCalcET8 5.1    Integrals
# 36   37    SCalcET8 5.5    Integrals
# 648  38    SCalcET8 6.1    Applications of Integration
# 497  39    SCalcET8 6.2    Applications of Integration
# 166  40    SCalcET8 6.3    Applications of Integration
# 18   41    SCalcET8 6.4    Applications of Integration
# 566  42    SCalcET8 6.5    Applications of Integration
# 544  43    SCalcET8 7.1    Techniques of Integration
# 629  44    SCalcET8 7.2    Techniques of Integration
# 87   47    SCalcET8 7.5    Techniques of Integration
# 210  48    SCalcET8 7.6    Techniques of Integration
# 153  49    SCalcET8 7.7    Techniques of Integration
# 227  50    SCalcET8 7.8    Techniques of Integration
# 466  51    SCalcET8 8.1    Further Applications of Integration
# 524  52    SCalcET8 8.2    Further Applications of Integration
# 190  53    SCalcET8 8.3    Further Applications of Integration
# 676  54    SCalcET8 8.4    Further Applications of Integration
# 128  55    SCalcET8 8.5    Further Applications of Integration
# 322  56    SCalcET8 9.1    Differential Equations
# 134  59    SCalcET8 9.4    Differential Equations
# 444  61    SCalcET8 9.6    Differential Equations
# 419  62    SCalcET8 10.1   Parametric Equations and Polar Coordinates
# 483  63    SCalcET8 10.2   Parametric Equations and Polar Coordinates
# 4    64    SCalcET8 10.3   Parametric Equations and Polar Coordinates
# 618  65    SCalcET8 10.4   Parametric Equations and Polar Coordinates
# 288  66    SCalcET8 10.5   Parametric Equations and Polar Coordinates
# 102  67    SCalcET8 10.6   Parametric Equations and Polar Coordinates
# 114  68    SCalcET8 11.1   Infinite Sequences and Series
# 252  69    SCalcET8 11.2   Infinite Sequences and Series
# 582  70    SCalcET8 11.3   Infinite Sequences and Series
# 272  71    SCalcET8 11.4   Infinite Sequences and Series
# 349  72    SCalcET8 11.5   Infinite Sequences and Series
# 393  73    SCalcET8 11.6   Infinite Sequences and Series
# 66   74    SCalcET8 11.7   Infinite Sequences and Series
# 376  75    SCalcET8 11.8   Infinite Sequences and Series
# 40   76    SCalcET8 11.9   Infinite Sequences and Series
# 654  77    SCalcET8 11.10  Infinite Sequences and Series
# 501  78    SCalcET8 11.11  Infinite Sequences and Series
# 171  79    SCalcET8 12.1   Vectors and the Geometry of Space
# 21   80    SCalcET8 12.2   Vectors and the Geometry of Space
# 571  81    SCalcET8 12.3   Vectors and the Geometry of Space
# 550  82    SCalcET8 12.4   Vectors and the Geometry of Space
# 310  84    SCalcET8 12.6   Vectors and the Geometry of Space
# 607  85    SCalcET8 13.1   Vector Functions
# 214  87    SCalcET8 13.3   Vector Functions
# 158  88    SCalcET8 13.4   Vector Functions
# 235  89    SCalcET8 14.1   Partial Derivatives
# 473  90    SCalcET8 14.2   Partial Derivatives
# 528  91    SCalcET8 14.3   Partial Derivatives
# 194  92    SCalcET8 14.4   Partial Derivatives
# 682  93    SCalcET8 14.5   Partial Derivatives
# 335  95    SCalcET8 14.7   Partial Derivatives
# 448  96    SCalcET8 14.8   Partial Derivatives
# 425  97    SCalcET8 15.1   Multiple Integrals
# 489  98    SCalcET8 15.2   Multiple Integrals
# 9    99    SCalcET8 15.3   Multiple Integrals
# 295  101   SCalcET8 15.5   Multiple Integrals
# 106  102   SCalcET8 15.6   Multiple Integrals
# 120  103   SCalcET8 15.7   Multiple Integrals
# 262  104   SCalcET8 15.8   Multiple Integrals
# 586  105   SCalcET8 15.9   Multiple Integrals
# 274  106   SCalcET8 16.1   Vector Calculus
# 397  108   SCalcET8 16.3   Vector Calculus
# 379  110   SCalcET8 16.5   Vector Calculus
# 45   111   SCalcET8 16.6   Vector Calculus
# 663  112   SCalcET8 16.7   Vector Calculus
# 507  113   SCalcET8 16.8   Vector Calculus
# 176  114   SCalcET8 16.9   Vector Calculus
# 574  116   SCalcET8 17.1   Second-Order Differential Equations
# 554  117   SCalcET8 17.2   Second-Order Differential Equations
# 640  118   SCalcET8 17.3   Second-Order Differential Equations
# 313  119   SCalcET8 17.4   Second-Order Differential Equations
#
#                                                sectionname  topic  \
# 51   Four Ways to Represent a Function                      2
# 360  Mathematical Models: A Catalog of Essential Functions  2
# 31   New Functions from Old Functions                       2
# 644  Exponential Functions                                  2
# 492  Inverse Functions and Logarithms                       2
# 163  The Tangent and Velocity Problems                      17
# 12   The Limit of a Function                                18
# 558  Calculating Limits Using the Limit Laws                18
# 538  The Precise Definition of a Limit                      18
# 624  Continuity                                             7
# 298  Limits at Infinity; Horizontal Asymptotes              18
# 591  Derivatives and Rates of Change                        17
# 79   The Derivative as a Function                           2
# 667  Rates of Change in the Natural and Social Sciences     1
# 123  Exponential Growth and Decay                           12
# 315  Related Rates                                          1
# 431  Linear Approximations and Differentials                4
# 404  Hyperbolic Functions                                   2
# 477  Maximum and Minimum Values                             11
# 0    The Mean Value Theorem                                 7
# 611  How Derivatives Affect the Shape of a Graph            11
# 278  Indeterminate Forms and l���Hospital���s Rule          18
# 110  Graphing with Calculus                                 11
# 578  Newton���s Method                                      14
# 342  Areas and Distances                                    6
# 36   The Substitution Rule                                  8
# 648  Areas between Curves                                   6
# 497  Volumes                                                0
# 166  Volumes by Cylindrical Shells                          0
# 18   Work                                                   1
# 566  Average Value of a Function                            1
# 544  Integration by Parts                                   8
# 629  Trigonometric Integrals                                8
# 87   Strategy for Integration                               8
# 210  Integration Using Tables and Computer Algebra Systems  8
# 153  Approximate Integration                                4
# 227  Improper Integrals                                     8
# 466  Arc Length                                             3
# 524  Area of a Surface of Revolution                        6
# 190  Applications to Physics and Engineering                1
# 676  Applications to Economics and Biology                  1
# 128  Probability                                            1
# 322  Modeling with Differential Equations                   12
# 134  Models for Population Growth                           12
# 444  Predator-Prey Systems                                  12
# 419  Curves Defined by Parametric Equations                 3
# 483  Calculus with Parametric Curves                        3
# 4    Polar Coordinates                                      3
# 618  Areas and Lengths in Polar Coordinates                 6
# 288  Conic Sections                                         19
# 102  Conic Sections in Polar Coordinates                    19
# 114  Sequences                                              10
# 252  Series                                                 10
# 582  The Integral Test and Estimates of Sums                10
# 272  The Comparison Tests                                   10
# 349  Alternating Series                                     10
# 393  Absolute Convergence and the Ratio and Root Tests      10
# 66   Strategy for Testing Series                            10
# 376  Power Series                                           16
# 40   Representations of Functions as Power Series           16
# 654  Taylor and Maclaurin Series                            16
# 501  Applications of Taylor Polynomials                     4
# 171  Three-Dimensional Coordinate Systems                   0
# 21   Vectors                                                5
# 571  The Dot Product                                        5
# 550  The Cross Product                                      5
# 310  Cylinders and Quadric Surfaces                         9
# 607  Vector Functions and Space Curves                      3
# 214  Arc Length and Curvature                               3
# 158  Motion in Space: Velocity and Acceleration             1
# 235  Functions of Several Variables                         2
# 473  Limits and Continuity                                  7
# 528  Partial Derivatives                                    4
# 194  Tangent Planes and Linear Approximations               4
# 682  The Chain Rule                                         4
# 335  Maximum and Minimum Values                             11
# 448  Lagrange Multipliers                                   11
# 425  Double Integrals over Rectangles                       0
# 489  Double Integrals over General Regions                  0
# 9    Double Integrals in Polar Coordinates                  0
# 295  Surface Area                                           9
# 106  Triple Integrals                                       0
# 120  Triple Integrals in Cylindrical Coordinates            0
# 262  Triple Integrals in Spherical Coordinates              0
# 586  Change of Variables in Multiple Integrals              0
# 274  Vector Fields                                          13
# 397  The Fundamental Theorem for Line Integrals             13
# 379  Curl and Divergence                                    13
# 45   Parametric Surfaces and Their Areas                    9
# 663  Surface Integral                                       9
# 507  Stokes��� Theorem                                      9
# 176  The Divergence Theorem                                 9
# 574  Second-Order Linear Equations                          15
# 554  Nonhomogeneous Linear Equations                        15
# 640  Applications of Second-Order Differential Equations    1
# 313  Series Solutions                                       16
#
#                                                                                            terms
# 51   [function, graph, domain, figure, exponential, loweralpha, model, sketch, inverse, time]
# 360  [function, graph, domain, figure, exponential, loweralpha, model, sketch, inverse, time]
# 31   [function, graph, domain, figure, exponential, loweralpha, model, sketch, inverse, time]
# 644  [function, graph, domain, figure, exponential, loweralpha, model, sketch, inverse, time]
# 492  [function, graph, domain, figure, exponential, loweralpha, model, sketch, inverse, time]
# 163  [line, tangent, velocity, slope, average, time, point, secant, rate, problem]
# 12   [limx, limit, graph, exist, approach, large, value, law, asymptote, numb]
# 558  [limx, limit, graph, exist, approach, large, value, law, asymptote, numb]
# 538  [limx, limit, graph, exist, approach, large, value, law, asymptote, numb]
# 624  [function, continuous, limx, theorem, limit, y2, numb, exist, lim, x2]
# 298  [limx, limit, graph, exist, approach, large, value, law, asymptote, numb]
# 591  [line, tangent, velocity, slope, average, time, point, secant, rate, problem]
# 79   [function, graph, domain, figure, exponential, loweralpha, model, sketch, inverse, time]
# 667  [ft, force, work, rate, mass, length, cm, time, velocity, density]
# 123  [population, equation, model, solution, rate, differential, growth, logistic, year, time]
# 315  [ft, force, work, rate, mass, length, cm, time, velocity, density]
# 431  [approximation, error, rule, dx, estimate, linear, dy, derivative, tangent, method]
# 404  [function, graph, domain, figure, exponential, loweralpha, model, sketch, inverse, time]
# 477  [maximum, minimum, graph, point, value, absolute, interval, derivative, critical, function]
# 0    [function, continuous, limx, theorem, limit, y2, numb, exist, lim, x2]
# 611  [maximum, minimum, graph, point, value, absolute, interval, derivative, critical, function]
# 278  [limx, limit, graph, exist, approach, large, value, law, asymptote, numb]
# 110  [maximum, minimum, graph, point, value, absolute, interval, derivative, critical, function]
# 578  [approximation, x2, method, x1, newton, xn, equation, x3, root, place]
# 342  [area, surface, curve, find, region, lie, rotate, part, rectangle, length]
# 36   [dx, integral, ln, evaluate, 2x, dt, substitution, x2, sec, integration]
# 648  [area, surface, curve, find, region, lie, rotate, part, rectangle, length]
# 497  [x2, y2, integral, region, coordinate, plane, solid, dy, volume, diagram]
# 166  [x2, y2, integral, region, coordinate, plane, solid, dy, volume, diagram]
# 18   [ft, force, work, rate, mass, length, cm, time, velocity, density]
# 566  [ft, force, work, rate, mass, length, cm, time, velocity, density]
# 544  [dx, integral, ln, evaluate, 2x, dt, substitution, x2, sec, integration]
# 629  [dx, integral, ln, evaluate, 2x, dt, substitution, x2, sec, integration]
# 87   [dx, integral, ln, evaluate, 2x, dt, substitution, x2, sec, integration]
# 210  [dx, integral, ln, evaluate, 2x, dt, substitution, x2, sec, integration]
# 153  [approximation, error, rule, dx, estimate, linear, dy, derivative, tangent, method]
# 227  [dx, integral, ln, evaluate, 2x, dt, substitution, x2, sec, integration]
# 466  [curve, point, graph, length, parametric, figure, equation, polar, find, exercise]
# 524  [area, surface, curve, find, region, lie, rotate, part, rectangle, length]
# 190  [ft, force, work, rate, mass, length, cm, time, velocity, density]
# 676  [ft, force, work, rate, mass, length, cm, time, velocity, density]
# 128  [ft, force, work, rate, mass, length, cm, time, velocity, density]
# 322  [population, equation, model, solution, rate, differential, growth, logistic, year, time]
# 134  [population, equation, model, solution, rate, differential, growth, logistic, year, time]
# 444  [population, equation, model, solution, rate, differential, growth, logistic, year, time]
# 419  [curve, point, graph, length, parametric, figure, equation, polar, find, exercise]
# 483  [curve, point, graph, length, parametric, figure, equation, polar, find, exercise]
# 4    [curve, point, graph, length, parametric, figure, equation, polar, find, exercise]
# 618  [area, surface, curve, find, region, lie, rotate, part, rectangle, length]
# 288  [focus, polar, equation, ellipse, directrix, conic, axis, hyperbola, eccentricity, figure]
# 102  [focus, polar, equation, ellipse, directrix, conic, axis, hyperbola, eccentricity, figure]
# 114  [series, convergent, sum, term, limn, test, bn, sequence, sn, sidebar]
# 252  [series, convergent, sum, term, limn, test, bn, sequence, sn, sidebar]
# 582  [series, convergent, sum, term, limn, test, bn, sequence, sn, sidebar]
# 272  [series, convergent, sum, term, limn, test, bn, sequence, sn, sidebar]
# 349  [series, convergent, sum, term, limn, test, bn, sequence, sn, sidebar]
# 393  [series, convergent, sum, term, limn, test, bn, sequence, sn, sidebar]
# 66   [series, convergent, sum, term, limn, test, bn, sequence, sn, sidebar]
# 376  [series, power, convergence, xn, sum, cn, converge, 2n, radius, term]
# 40   [series, power, convergence, xn, sum, cn, converge, 2n, radius, term]
# 654  [series, power, convergence, xn, sum, cn, converge, 2n, radius, term]
# 501  [approximation, error, rule, dx, estimate, linear, dy, derivative, tangent, method]
# 171  [x2, y2, integral, region, coordinate, plane, solid, dy, volume, diagram]
# 21   [vector, a2, product, a1, angle, a3, direction, sidebar, force, point]
# 571  [vector, a2, product, a1, angle, a3, direction, sidebar, force, point]
# 550  [vector, a2, product, a1, angle, a3, direction, sidebar, force, point]
# 310  [surface, y2, x2, plane, area, z2, d, lie, part, axis]
# 607  [curve, point, graph, length, parametric, figure, equation, polar, find, exercise]
# 214  [curve, point, graph, length, parametric, figure, equation, polar, find, exercise]
# 158  [ft, force, work, rate, mass, length, cm, time, velocity, density]
# 235  [function, graph, domain, figure, exponential, loweralpha, model, sketch, inverse, time]
# 473  [function, continuous, limx, theorem, limit, y2, numb, exist, lim, x2]
# 528  [approximation, error, rule, dx, estimate, linear, dy, derivative, tangent, method]
# 194  [approximation, error, rule, dx, estimate, linear, dy, derivative, tangent, method]
# 682  [approximation, error, rule, dx, estimate, linear, dy, derivative, tangent, method]
# 335  [maximum, minimum, graph, point, value, absolute, interval, derivative, critical, function]
# 448  [maximum, minimum, graph, point, value, absolute, interval, derivative, critical, function]
# 425  [x2, y2, integral, region, coordinate, plane, solid, dy, volume, diagram]
# 489  [x2, y2, integral, region, coordinate, plane, solid, dy, volume, diagram]
# 9    [x2, y2, integral, region, coordinate, plane, solid, dy, volume, diagram]
# 295  [surface, y2, x2, plane, area, z2, d, lie, part, axis]
# 106  [x2, y2, integral, region, coordinate, plane, solid, dy, volume, diagram]
# 120  [x2, y2, integral, region, coordinate, plane, solid, dy, volume, diagram]
# 262  [x2, y2, integral, region, coordinate, plane, solid, dy, volume, diagram]
# 586  [x2, y2, integral, region, coordinate, plane, solid, dy, volume, diagram]
# 274  [vector, field, curl, y2, exercise, direction, div, velocity, point, gradient]
# 397  [vector, field, curl, y2, exercise, direction, div, velocity, point, gradient]
# 379  [vector, field, curl, y2, exercise, direction, div, velocity, point, gradient]
# 45   [surface, y2, x2, plane, area, z2, d, lie, part, axis]
# 663  [surface, y2, x2, plane, area, z2, d, lie, part, axis]
# 507  [surface, y2, x2, plane, area, z2, d, lie, part, axis]
# 176  [surface, y2, x2, plane, area, z2, d, lie, part, axis]
# 574  [solution, equation, differential, c1, sidebar, c2, yp, solve, y1, problem]
# 554  [solution, equation, differential, c1, sidebar, c2, yp, solve, y1, problem]
# 640  [ft, force, work, rate, mass, length, cm, time, velocity, density]
# 313  [series, power, convergence, xn, sum, cn, converge, 2n, radius, term]
